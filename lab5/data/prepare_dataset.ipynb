# %% [markdown]
# # Dataset: "Student Performance"

# %%
# !pip install -q kagglehub pandas
import kagglehub


path = kagglehub.dataset_download("harlfoxem/housesalesprediction", "kc_house_data.csv")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/marcin/.cache/kagglehub/datasets/harlfoxem/housesalesprediction/versions/1/kc_house_data.csv

# %%
import pandas as pd

df = pd.read_csv(path)

# %% [markdown]
# ### Drop not numerical columns and null values

# %%
df = df.drop(columns=["date", "id"])
df = df.dropna()
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
df.to_csv("kc_house_data.csv", index=False)
