# %% [markdown]
# # Dataset: "Monthly average earth surface temperature"
# [Dtaset Origin](https://ourworldindata.org/grapher/monthly-average-surface-temperatures-by-year)

# %%
import pandas as pd

df = pd.read_csv("monthly-average-surface-temperatures-by-year.csv")
df = df.rename(columns={"Year": "Month"})
df.head(5)
# Out:
#         Entity Code  Month       2025       2024       2023       2022  \
# 0  Afghanistan  AFG      1  -1.812812   3.300064  -4.335608  -0.322859
# 1  Afghanistan  AFG      2   1.728558   1.024550   4.187041   2.165870
# 2  Afghanistan  AFG      3   6.922349   5.843506  10.105444  10.483686
# 3  Afghanistan  AFG      4  16.707405  11.627398  14.277164  17.227650
# 4  Afghanistan  AFG      5  21.536873  18.957850  19.078170  19.962734
#
#         2021       2020       2019  ...       1959       1958       1956  \
# 0  -1.001608  -2.560545   0.585145  ...  -2.333814   0.576404  -3.351925
# 1   5.688000   2.880046   0.068664  ...  -1.545529   0.264962   0.455350
# 2   9.777976   6.916731   5.758049  ...   5.942937   7.716459   5.090270
# 3  15.168276  12.686832  13.838840  ...  13.752827  14.712909  11.982360
# 4  19.885902  18.884047  18.461287  ...  17.388723  16.352045  20.125462
#
#         1954       1952       1957       1955       1953       1951       1950
# ...

# %%
# pick average Word temperature
df = df[df.Entity == "World"]
# drop code and year 2025 (not complete data)
df = df.drop(columns=["Code", "2025"])

# %%
df
# Out:
#      Entity  Month       2024       2023       2022       2021       2020  \
# 2508  World      1  13.140137  12.688526  12.719246  12.685204  13.023134
# 2509  World      2  13.539749  13.022077  12.959181  12.789691  13.328617
# 2510  World      3  14.137102  13.920588  13.803046  13.598597  13.896722
# 2511  World      4  15.031858  14.682203  14.644942  14.552206  14.881941
# 2512  World      5  15.913483  15.656947  15.517449  15.518996  15.727563
# 2513  World      6  16.657152  16.514093  16.290827  16.195406  16.343060
# 2514  World      7  16.907806  16.953165  16.606314  16.559742  16.554218
# 2515  World      8  16.822422  16.820910  16.407060  16.422468  16.378103
# 2516  World      9  16.174273  16.376972  15.795761  15.847732  15.879856
# 2517  World     10  15.245267  15.296179  14.855305  14.867675  14.822323
# 2518  World     11  14.098477  14.224238  13.532649  13.716454  13.907555
# 2519  World     12  13.423883  13.510272  12.935972  12.987495  12.900242
#
# ...

# %%
# change format from wide to long, apply datatime
import numpy as np
import datetime

# [Date, Temp]
rows = []

for i, r in df.iterrows():
    years_temp = r.iloc[2:]
    month = r[1]
    for year, temp in years_temp.items():
        date = datetime.datetime(year=int(year), month=month, day=1)
        row = [date, temp]
        rows.append(row)
# Out:
# /tmp/ipykernel_5861/3398232380.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   month = r[1]

# %%
world_df = pd.DataFrame(rows, columns=["date", "temp"])

# %%
world_df.to_csv("world_avg_temp.csv", index=False)
